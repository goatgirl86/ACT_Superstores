# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("Superstore.xls")
df.head(5)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.rename(columns = {'Sub-Category':'SubCategory'}, inplace = True)

# %%
df.rename(columns={"Row ID":"Row_ID", "Order ID":"Order_ID", "Order Date":"Order_Date", "Ship Date":"Ship_Date", "Ship Mode":"Ship_Mode", "Customer ID":"Customer_ID", "Customer Name":"Customer_Name", "Postal Code":"Postal_Code", "Product ID":"Product_ID", "Product Name":"Product_Name"}, inplace=True)
df.head(5)
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_ID         Category SubCategory  \
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.Category.value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df.SubCategory.value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: SubCategory, dtype: int64

# %%
df.City.value_counts()
# Out:
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64

# %%
df.Region.value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
region_mean=df.groupby(["Region"]).mean()
region_mean
# Out:
# C:\Users\twmgp\AppData\Local\Temp\ipykernel_23940\563718230.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   region_mean=df.groupby(["Region"]).mean()
#               Row_ID   Postal_Code       Sales  Quantity  Discount     Profit
# Region
# Central  5030.547998  65340.572536  215.772661  3.779595  0.240353  17.092709
# East     4941.685042  17616.466994  238.336110  3.728230  0.145365  32.135808
# South    5069.935185  34490.772840  241.803645  3.832716  0.147253  28.857673
# West     4986.524508  91707.696534  226.493233  3.829535  0.109335  33.849032

# %%
region_sum=df.groupby(["Region"]).sum()
region_sum
# Out:
# C:\Users\twmgp\AppData\Local\Temp\ipykernel_23940\2366756502.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   region_sum=df.groupby(["Region"]).sum()
#            Row_ID  Postal_Code        Sales  Quantity  Discount       Profit
# Region
# Central  11685963    151786150  501239.8908      8780    558.34   39706.3625
# East     14073919     50171698  678781.2400     10618    414.00   91522.7800
# South     8213295     55875052  391721.9050      6209    238.55   46749.4303
# West     15971838    293739752  725457.8245     12266    350.20  108418.4489

# %%
df_sub=df.loc[(df["Region"]=='South')&(df["Category"]=='Office Supplies')]
df_sub.head(5)
# Out:
#     Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 4        5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 12      13  CA-2017-114412 2017-04-15 2017-04-20  Standard Class    AA-10480
# 43      44  CA-2017-139619 2017-09-19 2017-09-23  Standard Class    ES-14080
# 69      70  CA-2016-119823 2016-06-04 2016-06-06     First Class    KD-16270
# 74      75  US-2015-134026 2015-04-26 2015-05-02  Standard Class    JE-15745
#
#      Customer_Name    Segment        Country             City  ...  \
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 12    Andrew Allen   Consumer  United States          Concord  ...
# 43      Erin Smith  Corporate  United States        Melbourne  ...
# 69   Karen Daniels   Consumer  United States      Springfield  ...
# 74      Joel Eaton   Consumer  United States          Memphis  ...
#
#    Postal_Code  Region       Product_ID         Category Sub-Category  \
# ...

# %%
df_csr = df.groupby(['Category','Segment','Region'], as_index=False)['Profit'].mean()
df_csr.head(5).append(df_csr.tail(5))
# Out:
# C:\Users\twmgp\AppData\Local\Temp\ipykernel_23940\1000373357.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_csr.head(5).append(df_csr.tail(5))
#       Category      Segment   Region      Profit
# 0    Furniture     Consumer  Central  -15.664448
# 1    Furniture     Consumer     East    6.726443
# 2    Furniture     Consumer    South   25.648514
# 3    Furniture     Consumer     West   11.548448
# 4    Furniture    Corporate  Central   16.948861
# 31  Technology    Corporate     West   62.518655
# 32  Technology  Home Office  Central   89.632284
# 33  Technology  Home Office     East  180.704770
# 34  Technology  Home Office    South   13.901365
# 35  Technology  Home Office     West   43.179418

# %%
df_c = df.groupby(['Category'], as_index=False)['Profit'].sum()
df_c
# Out:
#           Category       Profit
# 0        Furniture   18451.2728
# 1  Office Supplies  122490.8008
# 2       Technology  145454.9481

# %%
df_s = df.groupby(['State'], as_index=False)['Profit'].mean().sort_values(['Profit'],ascending=False)
# df_s=df_s.set_index(['State'])
df_s.head(5)
# Out:
#            State      Profit
# 43       Vermont  204.088936
# 37  Rhode Island  130.100523
# 12       Indiana  123.375411
# 24       Montana  122.221900
# 21     Minnesota  121.608847

# %%
state_mean=df.groupby("State")["Profit"].agg([np.mean, np.sum]).sort_values(['sum'], ascending=False)
state_mean.head(5)
# Out:
#                  mean         sum
# State
# California  38.171608  76381.3871
# New York    65.637011  74038.5486
# Washington  66.013146  33402.6517
# Michigan    95.934069  24463.1876
# Virginia    83.026564  18597.9504

# %%
state_mean=df.groupby("State")["Sales"].agg([np.mean, np.sum]).sort_values(['mean'], ascending=False)
state_mean.head(5)
# Out:
#                      mean        sum
# State
# Wyoming       1603.136000   1603.136
# Vermont        811.760909   8929.370
# Nevada         428.951333  16729.102
# Rhode Island   404.070643  22627.956
# Montana        372.623467   5589.352

# %%
df_scsr = df.groupby(['State','Region'], as_index=False)['Profit'].mean()
df_scsr.head(5)
# Out:
#         State Region     Profit
# 0     Alabama  South  94.865989
# 1     Arizona   West -15.303235
# 2    Arkansas  South  66.811452
# 3  California   West  38.171608
# 4    Colorado   West -35.867351

# %%
df_scsr['Percent Of Region Sales'] = df_scsr['Profit'] / df_scsr.groupby('Region')['Profit'].transform('sum')
df_scsr.head()
# Out:
#         State Region     Profit  Percent Of Region Sales
# 0     Alabama  South  94.865989                 0.189838
# 1     Arizona   West -15.303235                -0.032590
# 2    Arkansas  South  66.811452                 0.133698
# 3  California   West  38.171608                 0.081291
# 4    Colorado   West -35.867351                -0.076384

# %%
state_mean2=df.groupby(["State", "Region"])["Profit"].agg([np.mean, np.sum]).sort_values(['mean'], ascending=False)
state_mean2.head(5)
# Out:
#                             mean         sum
# State        Region
# Vermont      East     204.088936   2244.9783
# Rhode Island East     130.100523   7285.6293
# Indiana      Central  123.375411  18382.9363
# Montana      West     122.221900   1833.3285
# Minnesota    Central  121.608847  10823.1874

# %%
state_mean2['Percent Of Region Mean Sales'] = state_mean2['mean'] / state_mean2.groupby('Region')['mean'].transform('sum') * 100
state_mean2.head(5)
# Out:
#                             mean         sum  Percent Of Region Mean Sales
# State        Region
# Vermont      East     204.088936   2244.9783                     21.511500
# Rhode Island East     130.100523   7285.6293                     13.712931
# Indiana      Central  123.375411  18382.9363                     16.893444
# Montana      West     122.221900   1833.3285                     26.028708
# Minnesota    Central  121.608847  10823.1874                     16.651553

# %%
state_mean2['Percent Of Region Sum Sales'] = state_mean2['sum'] / state_mean2.groupby('Region')['sum'].transform('sum') * 100
state_mean2.head(5)
# Out:
#                             mean         sum  Percent Of Region Mean Sales  \
# State        Region
# Vermont      East     204.088936   2244.9783                     21.511500
# Rhode Island East     130.100523   7285.6293                     13.712931
# Indiana      Central  123.375411  18382.9363                     16.893444
# Montana      West     122.221900   1833.3285                     26.028708
# Minnesota    Central  121.608847  10823.1874                     16.651553
#
#                       Percent Of Region Sum Sales
# State        Region
# Vermont      East                        2.452918
# Rhode Island East                        7.960455
# Indiana      Central                    46.297206
# Montana      West                        1.690975
# Minnesota    Central                    27.258068

# %%
state_mean2=state_mean2.sort_values(['Region','mean'], ascending=False)
state_mean2.head(5)
# Out:
#                          mean         sum  Percent Of Region Mean Sales  \
# State      Region
# Montana    West    122.221900   1833.3285                     26.028708
# Wyoming    West    100.196000    100.1960                     21.338013
# Nevada     West     85.045279   3316.7659                     18.111474
# Washington West     66.013146  33402.6517                     14.058339
# Utah       West     48.047802   2546.5335                     10.232391
#
#                    Percent Of Region Sum Sales
# State      Region
# Montana    West                       1.690975
# Wyoming    West                       0.092416
# Nevada     West                       3.059226
# Washington West                      30.809011
# Utah       West                       2.348801

# %%
df
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer_ID     Customer_Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df_csub = df.groupby(['Category','SubCategory','Segment'], as_index=False)['Sales','Profit', ].mean().sort_values(['Category','Profit'], ascending=False)
df_csub
# Out:
# C:\Users\twmgp\AppData\Local\Temp\ipykernel_2104\77950537.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_csub = df.groupby(['Category','SubCategory','Segment'], as_index=False)['Sales','Profit', ].mean().sort_values(['Category','Profit'], ascending=False)
#            Category  SubCategory      Segment        Sales      Profit
# 44       Technology      Copiers  Home Office  2529.198000  964.910415
# 43       Technology      Copiers    Corporate  2341.469300  949.513945
# 42       Technology      Copiers     Consumer  1994.830571  688.106017
# 41       Technology  Accessories  Home Office   229.175114   60.665948
# 40       Technology  Accessories    Corporate   212.293233   55.980090
# 50       Technology       Phones  Home Office   415.186000   53.689134
# 48       Technology       Phones     Consumer   376.791051   52.853913
# ...
