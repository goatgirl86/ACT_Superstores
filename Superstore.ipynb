# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_excel("Superstore.xls")
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.rename(columns={"Row ID":"Row_ID", "Order ID":"Order_ID", "Order Date":"Order_Date", "Ship Date":"Ship_Date", "Ship Mode":"Ship_Mode", "Customer ID":"Customer_ID", "Customer Name":"Customer_Name", "Postal Code":"Postal_Code", "Product ID":"Product_ID", "Product Name":"Product_Name"}, inplace=True)
df
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer_ID     Customer_Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.Category.value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df.rename(columns = {'Sub-Category':'SubCategory'}, inplace = True)

# %%
df.SubCategory.value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: SubCategory, dtype: int64

# %%
df.City.value_counts()
# Out:
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64

# %%
df.Region.value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
region_mean=df.groupby(["Region"]).mean()
region_mean
# Out:
# C:\Users\twmgp\AppData\Local\Temp\ipykernel_29588\563718230.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   region_mean=df.groupby(["Region"]).mean()
#               Row_ID   Postal_Code       Sales  Quantity  Discount     Profit
# Region
# Central  5030.547998  65340.572536  215.772661  3.779595  0.240353  17.092709
# East     4941.685042  17616.466994  238.336110  3.728230  0.145365  32.135808
# South    5069.935185  34490.772840  241.803645  3.832716  0.147253  28.857673
# West     4986.524508  91707.696534  226.493233  3.829535  0.109335  33.849032

# %%
region_sum=df.groupby(["Region"]).sum()
region_sum
# Out:
# C:\Users\twmgp\AppData\Local\Temp\ipykernel_29588\2366756502.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   region_sum=df.groupby(["Region"]).sum()
#            Row_ID  Postal_Code        Sales  Quantity  Discount       Profit
# Region
# Central  11685963    151786150  501239.8908      8780    558.34   39706.3625
# East     14073919     50171698  678781.2400     10618    414.00   91522.7800
# South     8213295     55875052  391721.9050      6209    238.55   46749.4303
# West     15971838    293739752  725457.8245     12266    350.20  108418.4489

# %%
df.head(1)
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date     Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer_Name   Segment        Country       City  ... Postal_Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product_ID   Category SubCategory                       Product_Name  \
# 0  FUR-BO-10001798  Furniture   Bookcases  Bush Somerset Collection Bookcase
#
#     Sales  Quantity  Discount   Profit
# 0  261.96         2       0.0  41.9136
#
# [1 rows x 21 columns]

# %%
df_order=df[['Row_ID', 'Order_ID','Order_Date', 'Ship_Date', 'Ship_Mode']]
df_order
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
# [9994 rows x 5 columns]

# %%
df.head(1)
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date     Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer_Name   Segment        Country       City  ... Postal_Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product_ID   Category SubCategory                       Product_Name  \
# 0  FUR-BO-10001798  Furniture   Bookcases  Bush Somerset Collection Bookcase
#
#     Sales  Quantity  Discount   Profit
# 0  261.96         2       0.0  41.9136
#
# [1 rows x 21 columns]

# %%
df_customer=df[['Row_ID', 'Order_ID', 'Customer_ID','Customer_Name','Segment','Country','City','Postal_Code','Region']]
df_product=df[['Row_ID','Order_ID','Product_ID','Category','SubCategory','Product_Name','Sales','Quantity','Discount','Profit']]

# %%
df_product['Sales']= round(df_product['Sales'],4)
df_product
# Out:
# C:\Users\twmgp\AppData\Local\Temp\ipykernel_29588\1417056781.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_product['Sales']= round(df_product['Sales'],4)
#       Row_ID        Order_ID       Product_ID         Category  SubCategory  \
# 0          1  CA-2016-152156  FUR-BO-10001798        Furniture    Bookcases
# 1          2  CA-2016-152156  FUR-CH-10000454        Furniture       Chairs
# 2          3  CA-2016-138688  OFF-LA-10000240  Office Supplies       Labels
# 3          4  US-2015-108966  FUR-TA-10000577        Furniture       Tables
# 4          5  US-2015-108966  OFF-ST-10000760  Office Supplies      Storage
# ...      ...             ...              ...              ...          ...
# ...

# %%
df_product['Profit']= round(df_product['Profit'],4)
df_product
# Out:
# C:\Users\twmgp\AppData\Local\Temp\ipykernel_29588\441411534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_product['Profit']= round(df_product['Profit'],4)
#       Row_ID        Order_ID       Product_ID         Category  SubCategory  \
# 0          1  CA-2016-152156  FUR-BO-10001798        Furniture    Bookcases
# 1          2  CA-2016-152156  FUR-CH-10000454        Furniture       Chairs
# 2          3  CA-2016-138688  OFF-LA-10000240  Office Supplies       Labels
# 3          4  US-2015-108966  FUR-TA-10000577        Furniture       Tables
# 4          5  US-2015-108966  OFF-ST-10000760  Office Supplies      Storage
# ...      ...             ...              ...              ...          ...
# ...

# %%
df_order.to_csv("order_info.csv", index=False)
df_customer.to_csv("customer_info.csv", index=False)
df_product.to_csv("product_info.csv", index=False)

# %%
df_product.to_csv("product_info.csv", index=False)

# %%
df_product
# Out:
#       Row_ID        Order_ID       Product_ID         Category  SubCategory  \
# 0          1  CA-2016-152156  FUR-BO-10001798        Furniture    Bookcases
# 1          2  CA-2016-152156  FUR-CH-10000454        Furniture       Chairs
# 2          3  CA-2016-138688  OFF-LA-10000240  Office Supplies       Labels
# 3          4  US-2015-108966  FUR-TA-10000577        Furniture       Tables
# 4          5  US-2015-108966  OFF-ST-10000760  Office Supplies      Storage
# ...      ...             ...              ...              ...          ...
# 9989    9990  CA-2014-110422  FUR-FU-10001889        Furniture  Furnishings
# 9990    9991  CA-2017-121258  FUR-FU-10000747        Furniture  Furnishings
# 9991    9992  CA-2017-121258  TEC-PH-10003645       Technology       Phones
# 9992    9993  CA-2017-121258  OFF-PA-10004041  Office Supplies        Paper
# 9993    9994  CA-2017-119914  OFF-AP-10002684  Office Supplies   Appliances
#
# ...

# %%
pip install sqlalchemy
# Out:
# ...
#
# ...
#      ---------------------------------------- 1.6/1.6 MB 2.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 190.9/190.9 kB 5.8 MB/s eta 0:00:00
# ...

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy as sql
import psycopg2
import config
from config import db_password
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Text, Time
from sqlite3 import connect
from sqlalchemy import inspect
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import func

# %%
pip install psycopg2
# Out:
# ...
#      ---------------------------------------- 1.2/1.2 MB 2.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy as sql
import psycopg2
import config
from config import db_password
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Text, Time
from sqlite3 import connect
from sqlalchemy import inspect
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import func
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [30], line 3
#       1 import sqlalchemy as sql
#       2 import psycopg2
# ----> 3 import config
#       4 from config import db_password
#       5 from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Text, Time
#
# ModuleNotFoundError: No module named 'config'

# %%
pip install config
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy as sql
import psycopg2
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Text, Time
from sqlite3 import connect
from sqlalchemy import inspect
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import func

# %%
pip install sys
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement sys (from versions: none)
# ERROR: No matching distribution found for sys

# %%
import sys  
sys.path.insert(0, "/Users/twmgp/Documents/Data Analytics/Classwork/")
import config

from config import db_password

# %%
# Create a new table with joins:

# Connect to sql database 
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5433/Alumni"
db = create_engine(db_string)
conn = db.connect()

# %%
# define your database query
query = """
SELECT oi.row_id,
oi.order_id, 
oi.order_date,
oi.ship_date, 
oi.ship_mode,
ci.customer_id, 
ci.customer_name,
ci.segment, 
ci.country,
ci.city,
ci.postal_code, 
ci.region,
pi.product_id,
pi.category,
pi.subcategory,
pi.product_name,
pi.sales,
pi.quantity,
pi.discount, 
pi.profit
FROM order_info AS oi
INNER JOIN customer_info as ci
ON (oi.row_id = ci.row_id)
INNER JOIN product_info AS pi
ON (oi.row_id = pi.row_id)
"""
#access the database with the query and return a dataframe
df_all = pd.read_sql(query, conn)
df_all.head(5)
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      customer_name    segment        country             city  postal_code  \
# 0      Claire Gute   Consumer  United States        Henderson        42420
# 1      Claire Gute   Consumer  United States        Henderson        42420
# 2  Darrin Van Huff  Corporate  United States      Los Angeles        90036
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale        33311
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale        33311
#
# ...

# %%
# define your database query
query = """
SELECT oi.row_id,
oi.order_id, 
oi.order_date,
oi.ship_date, 
oi.ship_mode,
ci.customer_id, 
ci.customer_name,
ci.segment, 
ci.country,
ci.city,
ci.postal_code, 
ci.region,
pi.product_id,
pi.category,
pi.subcategory,
pi.product_name,
pi.sales,
pi.quantity,
pi.discount, 
pi.profit
FROM order_info AS oi
INNER JOIN customer_info as ci
ON (oi.row_id = ci.row_id)
INNER JOIN product_info AS pi
ON (oi.row_id = pi.row_id)
WHERE ci.region = 'South'
"""
#access the database with the query and return a dataframe
df_south = pd.read_sql(query, conn)
df_south.head(5)
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 3       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4      13  CA-2017-114412  2017-04-15  2017-04-20  Standard Class    AA-10480
#
#     customer_name   segment        country             city  postal_code  \
# 0     Claire Gute  Consumer  United States        Henderson        42420
# 1     Claire Gute  Consumer  United States        Henderson        42420
# 2  Sean O'Donnell  Consumer  United States  Fort Lauderdale        33311
# 3  Sean O'Donnell  Consumer  United States  Fort Lauderdale        33311
# 4    Andrew Allen  Consumer  United States          Concord        28027
#
#   region       product_id         category subcategory  \
# ...

# %%
# Connect to sql database 
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5433/Alumni"
db = create_engine(db_string)
conn = db.connect()
# define your database query
query = """
SELECT oi.row_id,
oi.order_id, 
oi.order_date,
oi.ship_date, 
oi.ship_mode,
ci.customer_id, 
ci.customer_name,
ci.segment, 
ci.country,
ci.city,
ci.postal_code, 
ci.region,
pi.product_id,
pi.category,
pi.subcategory,
pi.product_name,
pi.sales,
pi.quantity,
pi.discount, 
pi.profit
FROM order_info AS oi
INNER JOIN customer_info as ci
ON (oi.row_id = ci.row_id)
INNER JOIN product_info AS pi
ON (oi.row_id = pi.row_id)
WHERE ci.region = 'East'
"""
#access the database with the query and return a dataframe
df_east = pd.read_sql(query, conn)
df_east.head(5)
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0      24  US-2017-156909  2017-07-16  2017-07-18    Second Class    SF-20065
# 1      28  US-2015-150630  2015-09-17  2015-09-21  Standard Class    TB-21520
# 2      29  US-2015-150630  2015-09-17  2015-09-21  Standard Class    TB-21520
# 3      30  US-2015-150630  2015-09-17  2015-09-21  Standard Class    TB-21520
# 4      31  US-2015-150630  2015-09-17  2015-09-21  Standard Class    TB-21520
#
#      customer_name   segment        country          city  postal_code region  \
# 0  Sandra Flanagan  Consumer  United States  Philadelphia        19140   East
# 1  Tracy Blumstein  Consumer  United States  Philadelphia        19140   East
# 2  Tracy Blumstein  Consumer  United States  Philadelphia        19140   East
# 3  Tracy Blumstein  Consumer  United States  Philadelphia        19140   East
# 4  Tracy Blumstein  Consumer  United States  Philadelphia        19140   East
#
# ...

# %%
# Connect to sql database 
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5433/Alumni"
db = create_engine(db_string)
conn = db.connect()
# define your database query
query = """
SELECT oi.row_id,
oi.order_id, 
oi.order_date,
oi.ship_date, 
oi.ship_mode,
ci.customer_id, 
ci.customer_name,
ci.segment, 
ci.country,
ci.city,
ci.postal_code, 
ci.region,
pi.product_id,
pi.category,
pi.subcategory,
pi.product_name,
pi.sales,
pi.quantity,
pi.discount, 
pi.profit
FROM order_info AS oi
INNER JOIN customer_info as ci
ON (oi.row_id = ci.row_id)
INNER JOIN product_info AS pi
ON (oi.row_id = pi.row_id)
WHERE ci.region = 'West'
"""
#access the database with the query and return a dataframe
df_west = pd.read_sql(query, conn)
df_west.head(5)
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 1       6  CA-2014-115812  2014-06-09  2014-06-14  Standard Class    BH-11710
# 2       7  CA-2014-115812  2014-06-09  2014-06-14  Standard Class    BH-11710
# 3       8  CA-2014-115812  2014-06-09  2014-06-14  Standard Class    BH-11710
# 4       9  CA-2014-115812  2014-06-09  2014-06-14  Standard Class    BH-11710
#
#      customer_name    segment        country         city  postal_code region  \
# 0  Darrin Van Huff  Corporate  United States  Los Angeles        90036   West
# 1  Brosina Hoffman   Consumer  United States  Los Angeles        90032   West
# 2  Brosina Hoffman   Consumer  United States  Los Angeles        90032   West
# 3  Brosina Hoffman   Consumer  United States  Los Angeles        90032   West
# 4  Brosina Hoffman   Consumer  United States  Los Angeles        90032   West
#
# ...

# %%
# Connect to sql database 
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5433/Alumni"
db = create_engine(db_string)
conn = db.connect()
# define your database query
query = """
SELECT oi.row_id,
oi.order_id, 
oi.order_date,
oi.ship_date, 
oi.ship_mode,
ci.customer_id, 
ci.customer_name,
ci.segment, 
ci.country,
ci.city,
ci.postal_code, 
ci.region,
pi.product_id,
pi.category,
pi.subcategory,
pi.product_name,
pi.sales,
pi.quantity,
pi.discount, 
pi.profit
FROM order_info AS oi
INNER JOIN customer_info as ci
ON (oi.row_id = ci.row_id)
INNER JOIN product_info AS pi
ON (oi.row_id = pi.row_id)
WHERE ci.region = 'Central'
"""
#access the database with the query and return a dataframe
df_central = pd.read_sql(query, conn)
df_central.head(5)
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0      15  US-2015-118983  2015-11-22  2015-11-26  Standard Class    HP-14815
# 1      16  US-2015-118983  2015-11-22  2015-11-26  Standard Class    HP-14815
# 2      17  CA-2014-105893  2014-11-11  2014-11-18  Standard Class    PK-19075
# 3      22  CA-2016-137330  2016-12-09  2016-12-13  Standard Class    KB-16585
# 4      23  CA-2016-137330  2016-12-09  2016-12-13  Standard Class    KB-16585
#
#    customer_name      segment        country        city  postal_code  \
# 0  Harold Pawlan  Home Office  United States  Fort Worth        76106
# 1  Harold Pawlan  Home Office  United States  Fort Worth        76106
# 2      Pete Kriz     Consumer  United States     Madison        53711
# 3      Ken Black    Corporate  United States     Fremont        68025
# 4      Ken Black    Corporate  United States     Fremont        68025
#
#     region       product_id         category subcategory  \
# ...

# %%
df_sub=df_all.loc[(df_all["region"]=='South')&(df_all["category"]=='Office Supplies')]
df_sub
# Out:
#       row_id        order_id  order_date   ship_date       ship_mode  \
# 4          5  US-2015-108966  2015-10-11  2015-10-18  Standard Class
# 12        13  CA-2017-114412  2017-04-15  2017-04-20  Standard Class
# 43        44  CA-2017-139619  2017-09-19  2017-09-23  Standard Class
# 69        70  CA-2016-119823  2016-06-04  2016-06-06     First Class
# 74        75  US-2015-134026  2015-04-26  2015-05-02  Standard Class
# ...      ...             ...         ...         ...             ...
# 9856    9857  CA-2014-120950  2014-11-06  2014-11-11  Standard Class
# 9881    9882  CA-2014-153927  2014-08-12  2014-08-13     First Class
# 9911    9912  US-2014-157231  2014-04-05  2014-04-09  Standard Class
# 9970    9971  CA-2015-103772  2015-06-28  2015-07-02  Standard Class
# 9971    9972  CA-2015-103772  2015-06-28  2015-07-02  Standard Class
#
#      customer_id       customer_name      segment        country  \
# 4       SO-20335      Sean O'Donnell     Consumer  United States
# ...

# %%
df = df_all.groupby(['category','segment','region'], as_index=False)['profit'].mean()
df
# Out:
#            category      segment   region      profit
# 0         Furniture     Consumer  Central  -15.664448
# 1         Furniture     Consumer     East    6.726443
# 2         Furniture     Consumer    South   25.648514
# 3         Furniture     Consumer     West   11.548448
# 4         Furniture    Corporate  Central   16.948861
# 5         Furniture    Corporate     East    1.727908
# 6         Furniture    Corporate    South    9.426043
# 7         Furniture    Corporate     West   18.898409
# 8         Furniture  Home Office  Central  -13.467518
# 9         Furniture  Home Office     East    6.659279
# 10        Furniture  Home Office    South   23.577318
# 11        Furniture  Home Office     West   26.275544
# 12  Office Supplies     Consumer  Central    3.495458
# 13  Office Supplies     Consumer     East   21.647176
# 14  Office Supplies     Consumer    South   18.198252
# 15  Office Supplies     Consumer     West   25.461676
# ...
